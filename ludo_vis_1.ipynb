# %%
import os

import numpy as np
from tqdm import tqdm
import csv
import sys

sys.path.append('../')
from DataBot.data_bot import BotMLP
from Boards.Speed_leedo_2p_v6 import FullBoard
from Intelligent_bot.intelligent_bot import Bot

env = FullBoard()
agent0 = BotMLP()
agent0.load_model("../DataBot/models/mlp_bot_models/model_{}.hdf5".format(44))
bot0 = Bot()

agent0_reward = []
agent1_reward = []
episode_length = []

s, _, game_over, player_turn = env.reset()
step = 0

episode_reward = [0.0, 0.0]

mat = []

while not game_over:
    
    player_turn_temp = env.get_player_turn()
    env.roll_dice()[0]
    player_turn = env.get_player_turn()

    if player_turn == player_turn_temp:

        state = env.return_state()

        mat.append(np.concatenate((np.array(state), np.expand_dims(player_turn,0)), 0))
        mat.append([state[0]])

        action_list = env.get_next_states(player_turn)

        if action_list:
            
            if player_turn == 0:
                s_t = env.convert_state(player_turn)
                action = agent0.act(np.array(s_t).astype('float32'), action_list)
            else:
                s_t = env.return_state()
                action = bot0.act(state=s_t, p=player_turn)

            new_s, reward, game_over, player_turn_temp = env.make_step(action)
# Out:
# 2022-10-26 05:51:30.824333: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-26 05:51:31.023977: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-10-26 05:51:31.860278: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2022-10-26 05:51:31.860401: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2022-10-26 05:51:31.860412: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# /nfs_storage/fs-mnt6/barathmohanU/miniconda3/envs/env1/lib/python3.10/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# 2022-10-26 05:51:33.349915: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-26 05:51:33.357855: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2022-10-26 05:51:33.357877: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2022-10-26 05:51:33.379000: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /nfs_storage/fs-mnt6/barathmohanU/ludo_bot/LudoRL/Intelligent_bot/intelligent_bot.py:140: RuntimeWarning: divide by zero encountered in divide
#   self.pawn_priority[i] = self.pawn_priority[i] * 0.1 / self.pawn_score[i]

# %%
x_pos = [6, 6, 6, 6, 6, 6,
     5, 4, 3, 2, 1, 0,
     0,
     0, 1, 2, 3, 4, 5,
     6, 6, 6, 6, 6, 6,
     7,
     8, 8, 8, 8, 8, 8,
     9, 10, 11, 12, 13, 14,
     14,
     14, 13, 12, 11, 10, 9,
     8, 8, 8, 8, 8, 8,
     7,
     7, 7, 7, 7, 7, 7,
     1, 2, 3, 4, 5, 6,
     7, 7, 7, 7, 7, 7,
     13, 12, 11, 10, 9, 8]

y_pos = [0, 1, 2, 3, 4, 5,
     6, 6, 6, 6, 6, 6,
     7,
     8, 8, 8, 8, 8, 8,
     9, 10, 11, 12, 13, 14,
     14,
     14, 13, 12, 11, 10, 9,
     8, 8, 8, 8, 8, 8,
     7,
     6, 6, 6, 6, 6, 6,
     5, 4, 3, 2, 1, 0,
     0,
     1, 2, 3, 4, 5, 6,
     7, 7, 7, 7, 7, 7,
     13, 12, 11, 10, 9, 8,
     7, 7, 7, 7, 7, 7]

# %%
from jupylet.app import App
from jupylet.sprite import Sprite
from jupylet.label import Label

dir = '../Ludo_vis/pyludo/pyludo/assets/'
dir1 = '../Ludo_app/assets/'

app = App(width=450, height=450)

board = Sprite(dir + 'ludoboard.png', width=app.width, height=app.width, x=app.width/2, y=app.height/2)

p1_1 = Sprite(dir + 'yellowPlayer.png', x=6*30+15, y=1*30+15, width=30)
p1_2 = Sprite(dir + 'yellowPlayer.png', x=6*30+15, y=1*30+15, width=30)
p1_3 = Sprite(dir + 'yellowPlayer.png', x=6*30+15, y=1*30+15, width=30)
p1_4 = Sprite(dir + 'yellowPlayer.png', x=6*30+15, y=1*30+15, width=30)

p2_1 = Sprite(dir + 'bluePlayer.png', x=8*30+15, y=13*30+15, width=30)
p2_2 = Sprite(dir + 'bluePlayer.png', x=8*30+15, y=13*30+15, width=30)
p2_3 = Sprite(dir + 'bluePlayer.png', x=8*30+15, y=13*30+15, width=30)
p2_4 = Sprite(dir + 'bluePlayer.png', x=8*30+15, y=13*30+15, width=30)

star_1 = Sprite(dir + 'star.png', x=2*30+15, y=6*30+15, width=20)
star_2 = Sprite(dir + 'star.png', x=6*30+15, y=12*30+15, width=20)
star_3 = Sprite(dir + 'star.png', x=12*30+15, y=8*30+15, width=20)
star_4 = Sprite(dir + 'star.png', x=8*30+15, y=2*30+15, width=20)

dice_1 = Sprite(dir1 + 'de1.png', x=800, y=800, width=80)
dice_2 = Sprite(dir1 + 'de2.png', x=800, y=800, width=80)
dice_3 = Sprite(dir1 + 'de3.png', x=800, y=800, width=80)
dice_4 = Sprite(dir1 + 'de4.png', x=800, y=800, width=80)
dice_5 = Sprite(dir1 + 'de5.png', x=800, y=800, width=80)
dice_6 = Sprite(dir1 + 'de6.png', x=800, y=800, width=80)

score_1 = Label('0', color='black', font_size=24, x=3*30-5, y=1*30-10)
score_2 = Label('0', color='black', font_size=24, x=12*30-5, y=14*30)

step = 0
max_step = len(mat) - 1

@app.event
def mouse_press_event(x, y, button):

    if button == 1:
        if globals()['step'] != max_step:
            globals()['step'] += 1
    else:
        if globals()['step'] != 0:
            globals()['step'] -= 1
    
    if len(mat[globals()['step']]) > 1:

        state1 = mat[globals()['step']][1:5]
        state2 = mat[globals()['step']][5:9]

        sco_1 = int(np.sum(mat[globals()['step']][9:13]))
        sco_2 = int(np.sum(mat[globals()['step']][13:17]))

        for i in range(4):
            globals()['p1_'+str(i+1)].x = globals()['x_pos'][state1[i]]*30+15
            globals()['p2_'+str(i+1)].x = globals()['x_pos'][state2[i]]*30+15

            globals()['p1_'+str(i+1)].y = globals()['y_pos'][state1[i]]*30+15
            globals()['p2_'+str(i+1)].y = globals()['y_pos'][state2[i]]*30+15

        score_1.text = str(sco_1)
        score_2.text = str(sco_2)

        if sco_1 > 9:
            score_1.x = 3*30-12
        if sco_2 > 9:
            score_2.x = 12*30-12
        if sco_1 > 99:
            score_1.x = 3*30-19
        if sco_2 > 99:
            score_2.x = 12*30-19

    else:
        roll = mat[globals()['step']][0]
        p = mat[globals()['step']-1][-1]

        dice_1.x = 800
        dice_2.x = 800
        dice_3.x = 800
        dice_4.x = 800
        dice_5.x = 800
        dice_6.x = 800

        dice_1.y = 800
        dice_2.y = 800
        dice_3.y = 800
        dice_4.y = 800
        dice_5.y = 800
        dice_6.y = 800

        if p == 0:
            globals()['dice_'+str(roll)].x = 3*30
            globals()['dice_'+str(roll)].y = 3*30
        else:
            globals()['dice_'+str(roll)].x = 12*30
            globals()['dice_'+str(roll)].y = 12*30

@app.event
def render(ct, dt):
    app.window.clear()
    board.draw()

    star_1.draw()
    star_2.draw()
    star_3.draw()
    star_4.draw()

    p1_1.draw()
    p1_2.draw()
    p1_3.draw()
    p1_4.draw()

    p2_1.draw()
    p2_2.draw()
    p2_3.draw()
    p2_4.draw()

    score_1.draw()
    score_2.draw()

    dice_1.draw()
    dice_2.draw()
    dice_3.draw()
    dice_4.draw()
    dice_5.draw()
    dice_6.draw()

# %%
app.run()
# Out:
# Image(value=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x08\x06\x0…
